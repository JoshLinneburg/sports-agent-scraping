# %%
import json
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup as bs

results = []

base_url = 'https://www.fiba.basketball/en/Module/06bcf0e2-3456-4ad6-8ecc-bf65747492c4'

params = {'PersonSearch.Freetext': None, 
          'PersonSearch.Country': None, 
          'PersonSearch.Nationality': None, 
          'PersonId': None, 
          'type': 'searchresults'}

response = requests.get(url=base_url, params=params)

html = bs(response.text)
table = html.find('tbody')
rows = table.findAll('tr')
agent_ids = [row['data-item-id'] for row in rows]

for agent_id in agent_ids:
    response = requests.get(url=base_url, params={'type': 'item', 'PersonId': agent_id})
    agent = bs(response.text)
    
    agent_name_html = agent.find('div', class_='group_right')
    agent_details_html = agent.find('div', class_='agent_details')
    
    try:
        first_name = agent_name_html.find('span', class_='firstname').text.strip()
    except AttributeError:
        first_name = None
        
    try:
        last_name = agent_name_html.find('span', class_='lastname').text.strip()
    except AttributeError:
        last_name = None

    try:
        licence_number = agent_name_html.find('div', class_='licence_number').text.strip('\n').split('\n')[1]
    except AttributeError:
        licence_number = None
    except IndexError:
        licence_number = None

    try:
        company = agent_details_html.find('div', class_='company').text.strip('\n').split('\n')[1]
    except AttributeError:
        company = None
    except IndexError:
        company = None
        
    try:
        address = agent_details_html.find('div', class_='address').text.strip('\n').split('\n')[1]
    except AttributeError:
        address = None
    except IndexError:
        address = None
        
    try:
        office_tel = agent_details_html.find('div', class_='office_tel').text.strip('\n').split('\n')[1]
    except AttributeError:
        office_tel = None
    except IndexError:
        office_tel = None
        
    try:
        office_mobile = agent_details_html.find('div', class_='office_mobile').text.strip('\n').split('\n')[1]
    except AttributeError:
        office_mobile = None
    except IndexError:
        office_mobile = None
        
    try:
        office_email = agent_details_html.find('div', class_='office_email').text.strip('\n').split('\n')[1]
    except AttributeError:
        office_email = None
    except IndexError:
        office_email = None
        
    try:
        website = agent_details_html.find('div', class_='website').text.strip('\n').split('\n')[1]
    except AttributeError:
        website = None
    except IndexError:
        website = None
    
    d = {
        'first_name': first_name,
        'last_name': last_name,
        'licence_number': licence_number,
        'company': company,
        'address': address,
        'office_tel': office_tel,
        'office_mobile': office_mobile,
        'office_email': office_email,
        'website': website
    }
    
    results.append(d)
    
    time.sleep(1)
    
    print(f'{len(results)} / {len(agent_ids)} agents scraped!')
    
df = pd.DataFrame(results)
df.to_csv('../data/nba_agents.csv', index=False)
# Out:
# 1 / 543 agents scraped!
# 2 / 543 agents scraped!
# 3 / 543 agents scraped!
# 4 / 543 agents scraped!
# 5 / 543 agents scraped!
# 6 / 543 agents scraped!
# 7 / 543 agents scraped!
# 8 / 543 agents scraped!
# 9 / 543 agents scraped!
# 10 / 543 agents scraped!
# 11 / 543 agents scraped!
# 12 / 543 agents scraped!
# 13 / 543 agents scraped!
# 14 / 543 agents scraped!
# 15 / 543 agents scraped!
# 16 / 543 agents scraped!
# 17 / 543 agents scraped!
# 18 / 543 agents scraped!
# 19 / 543 agents scraped!
# 20 / 543 agents scraped!
# 21 / 543 agents scraped!
# 22 / 543 agents scraped!
# 23 / 543 agents scraped!
# 24 / 543 agents scraped!
# 25 / 543 agents scraped!
# 26 / 543 agents scraped!
# 27 / 543 agents scraped!
# 28 / 543 agents scraped!
# 29 / 543 agents scraped!
# 30 / 543 agents scraped!
# 31 / 543 agents scraped!
# 32 / 543 agents scraped!
# 33 / 543 agents scraped!
# 34 / 543 agents scraped!
# 35 / 543 agents scraped!
# 36 / 543 agents scraped!
# 37 / 543 agents scraped!
# 38 / 543 agents scraped!
# 39 / 543 agents scraped!
# 40 / 543 agents scraped!
# 41 / 543 agents scraped!
# 42 / 543 agents scraped!
# 43 / 543 agents scraped!
# 44 / 543 agents scraped!
# 45 / 543 agents scraped!
# 46 / 543 agents scraped!
# 47 / 543 agents scraped!
# 48 / 543 agents scraped!
# 49 / 543 agents scraped!
# 50 / 543 agents scraped!
# 51 / 543 agents scraped!
# 52 / 543 agents scraped!
# 53 / 543 agents scraped!
# 54 / 543 agents scraped!
# 55 / 543 agents scraped!
# 56 / 543 agents scraped!
# 57 / 543 agents scraped!
# 58 / 543 agents scraped!
# 59 / 543 agents scraped!
# 60 / 543 agents scraped!
# 61 / 543 agents scraped!
# 62 / 543 agents scraped!
# 63 / 543 agents scraped!
# 64 / 543 agents scraped!
# 65 / 543 agents scraped!
# 66 / 543 agents scraped!
# 67 / 543 agents scraped!
# 68 / 543 agents scraped!
# 69 / 543 agents scraped!
# 70 / 543 agents scraped!
# 71 / 543 agents scraped!
# 72 / 543 agents scraped!
# 73 / 543 agents scraped!
# 74 / 543 agents scraped!
# 75 / 543 agents scraped!
# 76 / 543 agents scraped!
# 77 / 543 agents scraped!
# 78 / 543 agents scraped!
# 79 / 543 agents scraped!
# 80 / 543 agents scraped!
# 81 / 543 agents scraped!
# 82 / 543 agents scraped!
# 83 / 543 agents scraped!
# 84 / 543 agents scraped!
# 85 / 543 agents scraped!
# 86 / 543 agents scraped!
# 87 / 543 agents scraped!
# 88 / 543 agents scraped!
# 89 / 543 agents scraped!
# 90 / 543 agents scraped!
# 91 / 543 agents scraped!
# 92 / 543 agents scraped!
# 93 / 543 agents scraped!
# 94 / 543 agents scraped!
# 95 / 543 agents scraped!
# 96 / 543 agents scraped!
# 97 / 543 agents scraped!
# 98 / 543 agents scraped!
# 99 / 543 agents scraped!
# 100 / 543 agents scraped!
# 101 / 543 agents scraped!
# 102 / 543 agents scraped!
# 103 / 543 agents scraped!
# 104 / 543 agents scraped!
# 105 / 543 agents scraped!
# 106 / 543 agents scraped!
# 107 / 543 agents scraped!
# 108 / 543 agents scraped!
# 109 / 543 agents scraped!
# 110 / 543 agents scraped!
# 111 / 543 agents scraped!
# 112 / 543 agents scraped!
# 113 / 543 agents scraped!
# 114 / 543 agents scraped!
# 115 / 543 agents scraped!
# 116 / 543 agents scraped!
# 117 / 543 agents scraped!
# 118 / 543 agents scraped!
# 119 / 543 agents scraped!
# 120 / 543 agents scraped!
# 121 / 543 agents scraped!
# 122 / 543 agents scraped!
# 123 / 543 agents scraped!
# 124 / 543 agents scraped!
# 125 / 543 agents scraped!
# 126 / 543 agents scraped!
# 127 / 543 agents scraped!
# 128 / 543 agents scraped!
# 129 / 543 agents scraped!
# 130 / 543 agents scraped!
# 131 / 543 agents scraped!
# 132 / 543 agents scraped!
# 133 / 543 agents scraped!
# 134 / 543 agents scraped!
# 135 / 543 agents scraped!
# 136 / 543 agents scraped!
# 137 / 543 agents scraped!
# 138 / 543 agents scraped!
# 139 / 543 agents scraped!
# 140 / 543 agents scraped!
# 141 / 543 agents scraped!
# 142 / 543 agents scraped!
# 143 / 543 agents scraped!
# 144 / 543 agents scraped!
# 145 / 543 agents scraped!
# 146 / 543 agents scraped!
# 147 / 543 agents scraped!
# 148 / 543 agents scraped!
# 149 / 543 agents scraped!
# 150 / 543 agents scraped!
# 151 / 543 agents scraped!
# 152 / 543 agents scraped!
# 153 / 543 agents scraped!
# 154 / 543 agents scraped!
# 155 / 543 agents scraped!
# 156 / 543 agents scraped!
# 157 / 543 agents scraped!
# 158 / 543 agents scraped!
# 159 / 543 agents scraped!
# 160 / 543 agents scraped!
# 161 / 543 agents scraped!
# 162 / 543 agents scraped!
# 163 / 543 agents scraped!
# 164 / 543 agents scraped!
# 165 / 543 agents scraped!
# 166 / 543 agents scraped!
# 167 / 543 agents scraped!
# 168 / 543 agents scraped!
# 169 / 543 agents scraped!
# 170 / 543 agents scraped!
# 171 / 543 agents scraped!
# 172 / 543 agents scraped!
# 173 / 543 agents scraped!
# 174 / 543 agents scraped!
# 175 / 543 agents scraped!
# 176 / 543 agents scraped!
# 177 / 543 agents scraped!
# 178 / 543 agents scraped!
# 179 / 543 agents scraped!
# 180 / 543 agents scraped!
# 181 / 543 agents scraped!
# 182 / 543 agents scraped!
# 183 / 543 agents scraped!
# 184 / 543 agents scraped!
# 185 / 543 agents scraped!
# 186 / 543 agents scraped!
# 187 / 543 agents scraped!
# 188 / 543 agents scraped!
# 189 / 543 agents scraped!
# 190 / 543 agents scraped!
# 191 / 543 agents scraped!
# 192 / 543 agents scraped!
# 193 / 543 agents scraped!
# 194 / 543 agents scraped!
# 195 / 543 agents scraped!
# 196 / 543 agents scraped!
# 197 / 543 agents scraped!
# 198 / 543 agents scraped!
# 199 / 543 agents scraped!
# 200 / 543 agents scraped!
# 201 / 543 agents scraped!
# 202 / 543 agents scraped!
# 203 / 543 agents scraped!
# 204 / 543 agents scraped!
# 205 / 543 agents scraped!
# 206 / 543 agents scraped!
# 207 / 543 agents scraped!
# 208 / 543 agents scraped!
# 209 / 543 agents scraped!
# 210 / 543 agents scraped!
# 211 / 543 agents scraped!
# 212 / 543 agents scraped!
# 213 / 543 agents scraped!
# 214 / 543 agents scraped!
# 215 / 543 agents scraped!
# 216 / 543 agents scraped!
# 217 / 543 agents scraped!
# 218 / 543 agents scraped!
# 219 / 543 agents scraped!
# 220 / 543 agents scraped!
# 221 / 543 agents scraped!
# 222 / 543 agents scraped!
# 223 / 543 agents scraped!
# 224 / 543 agents scraped!
# 225 / 543 agents scraped!
# 226 / 543 agents scraped!
# 227 / 543 agents scraped!
# 228 / 543 agents scraped!
# 229 / 543 agents scraped!
# 230 / 543 agents scraped!
# 231 / 543 agents scraped!
# 232 / 543 agents scraped!
# 233 / 543 agents scraped!
# 234 / 543 agents scraped!
# 235 / 543 agents scraped!
# 236 / 543 agents scraped!
# 237 / 543 agents scraped!
# 238 / 543 agents scraped!
# 239 / 543 agents scraped!
# 240 / 543 agents scraped!
# 241 / 543 agents scraped!
# 242 / 543 agents scraped!
# 243 / 543 agents scraped!
# 244 / 543 agents scraped!
# 245 / 543 agents scraped!
# 246 / 543 agents scraped!
# 247 / 543 agents scraped!
# 248 / 543 agents scraped!
# 249 / 543 agents scraped!
# 250 / 543 agents scraped!
# 251 / 543 agents scraped!
# 252 / 543 agents scraped!
# 253 / 543 agents scraped!
# 254 / 543 agents scraped!
# 255 / 543 agents scraped!
# 256 / 543 agents scraped!
# 257 / 543 agents scraped!
# 258 / 543 agents scraped!
# 259 / 543 agents scraped!
# 260 / 543 agents scraped!
# 261 / 543 agents scraped!
# 262 / 543 agents scraped!
# 263 / 543 agents scraped!
# 264 / 543 agents scraped!
# 265 / 543 agents scraped!
# 266 / 543 agents scraped!
# 267 / 543 agents scraped!
# 268 / 543 agents scraped!
# 269 / 543 agents scraped!
# 270 / 543 agents scraped!
# 271 / 543 agents scraped!
# 272 / 543 agents scraped!
# 273 / 543 agents scraped!
# 274 / 543 agents scraped!
# 275 / 543 agents scraped!
# 276 / 543 agents scraped!
# 277 / 543 agents scraped!
# 278 / 543 agents scraped!
# 279 / 543 agents scraped!
# 280 / 543 agents scraped!
# 281 / 543 agents scraped!
# 282 / 543 agents scraped!
# 283 / 543 agents scraped!
# 284 / 543 agents scraped!
# 285 / 543 agents scraped!
# 286 / 543 agents scraped!
# 287 / 543 agents scraped!
# 288 / 543 agents scraped!
# 289 / 543 agents scraped!
# 290 / 543 agents scraped!
# 291 / 543 agents scraped!
# 292 / 543 agents scraped!
# 293 / 543 agents scraped!
# 294 / 543 agents scraped!
# 295 / 543 agents scraped!
# 296 / 543 agents scraped!
# 297 / 543 agents scraped!
# 298 / 543 agents scraped!
# 299 / 543 agents scraped!
# 300 / 543 agents scraped!
# 301 / 543 agents scraped!
# 302 / 543 agents scraped!
# 303 / 543 agents scraped!
# 304 / 543 agents scraped!
# 305 / 543 agents scraped!
# 306 / 543 agents scraped!
# 307 / 543 agents scraped!
# 308 / 543 agents scraped!
# 309 / 543 agents scraped!
# 310 / 543 agents scraped!
# 311 / 543 agents scraped!
# 312 / 543 agents scraped!
# 313 / 543 agents scraped!
# 314 / 543 agents scraped!
# 315 / 543 agents scraped!
# 316 / 543 agents scraped!
# 317 / 543 agents scraped!
# 318 / 543 agents scraped!
# 319 / 543 agents scraped!
# 320 / 543 agents scraped!
# 321 / 543 agents scraped!
# 322 / 543 agents scraped!
# 323 / 543 agents scraped!
# 324 / 543 agents scraped!
# 325 / 543 agents scraped!
# 326 / 543 agents scraped!
# 327 / 543 agents scraped!
# 328 / 543 agents scraped!
# 329 / 543 agents scraped!
# 330 / 543 agents scraped!
# 331 / 543 agents scraped!
# 332 / 543 agents scraped!
# 333 / 543 agents scraped!
# 334 / 543 agents scraped!
# 335 / 543 agents scraped!
# 336 / 543 agents scraped!
# 337 / 543 agents scraped!
# 338 / 543 agents scraped!
# 339 / 543 agents scraped!
# 340 / 543 agents scraped!
# 341 / 543 agents scraped!
# 342 / 543 agents scraped!
# 343 / 543 agents scraped!
# 344 / 543 agents scraped!
# 345 / 543 agents scraped!
# 346 / 543 agents scraped!
# 347 / 543 agents scraped!
# 348 / 543 agents scraped!
# 349 / 543 agents scraped!
# 350 / 543 agents scraped!
# 351 / 543 agents scraped!
# 352 / 543 agents scraped!
# 353 / 543 agents scraped!
# 354 / 543 agents scraped!
# 355 / 543 agents scraped!
# 356 / 543 agents scraped!
# 357 / 543 agents scraped!
# 358 / 543 agents scraped!
# 359 / 543 agents scraped!
# 360 / 543 agents scraped!
# 361 / 543 agents scraped!
# 362 / 543 agents scraped!
# 363 / 543 agents scraped!
# 364 / 543 agents scraped!
# 365 / 543 agents scraped!
# 366 / 543 agents scraped!
# 367 / 543 agents scraped!
# 368 / 543 agents scraped!
# 369 / 543 agents scraped!
# 370 / 543 agents scraped!
# 371 / 543 agents scraped!
# 372 / 543 agents scraped!
# 373 / 543 agents scraped!
# 374 / 543 agents scraped!
# 375 / 543 agents scraped!
# 376 / 543 agents scraped!
# 377 / 543 agents scraped!
# 378 / 543 agents scraped!
# 379 / 543 agents scraped!
# 380 / 543 agents scraped!
# 381 / 543 agents scraped!
# 382 / 543 agents scraped!
# 383 / 543 agents scraped!
# 384 / 543 agents scraped!
# 385 / 543 agents scraped!
# 386 / 543 agents scraped!
# 387 / 543 agents scraped!
# 388 / 543 agents scraped!
# 389 / 543 agents scraped!
# 390 / 543 agents scraped!
# 391 / 543 agents scraped!
# 392 / 543 agents scraped!
# 393 / 543 agents scraped!
# 394 / 543 agents scraped!
# 395 / 543 agents scraped!
# 396 / 543 agents scraped!
# 397 / 543 agents scraped!
# 398 / 543 agents scraped!
# 399 / 543 agents scraped!
# 400 / 543 agents scraped!
# 401 / 543 agents scraped!
# 402 / 543 agents scraped!
# 403 / 543 agents scraped!
# 404 / 543 agents scraped!
# 405 / 543 agents scraped!
# 406 / 543 agents scraped!
# 407 / 543 agents scraped!
# 408 / 543 agents scraped!
# 409 / 543 agents scraped!
# 410 / 543 agents scraped!
# 411 / 543 agents scraped!
# 412 / 543 agents scraped!
# 413 / 543 agents scraped!
# 414 / 543 agents scraped!
# 415 / 543 agents scraped!
# 416 / 543 agents scraped!
# 417 / 543 agents scraped!
# 418 / 543 agents scraped!
# 419 / 543 agents scraped!
# 420 / 543 agents scraped!
# 421 / 543 agents scraped!
# 422 / 543 agents scraped!
# 423 / 543 agents scraped!
# 424 / 543 agents scraped!
# 425 / 543 agents scraped!
# 426 / 543 agents scraped!
# 427 / 543 agents scraped!
# 428 / 543 agents scraped!
# 429 / 543 agents scraped!
# 430 / 543 agents scraped!
# 431 / 543 agents scraped!
# 432 / 543 agents scraped!
# 433 / 543 agents scraped!
# 434 / 543 agents scraped!
# 435 / 543 agents scraped!
# 436 / 543 agents scraped!
# 437 / 543 agents scraped!
# 438 / 543 agents scraped!
# 439 / 543 agents scraped!
# 440 / 543 agents scraped!
# 441 / 543 agents scraped!
# 442 / 543 agents scraped!
# 443 / 543 agents scraped!
# 444 / 543 agents scraped!
# 445 / 543 agents scraped!
# 446 / 543 agents scraped!
# 447 / 543 agents scraped!
# 448 / 543 agents scraped!
# 449 / 543 agents scraped!
# 450 / 543 agents scraped!
# 451 / 543 agents scraped!
# 452 / 543 agents scraped!
# 453 / 543 agents scraped!
# 454 / 543 agents scraped!
# 455 / 543 agents scraped!
# 456 / 543 agents scraped!
# 457 / 543 agents scraped!
# 458 / 543 agents scraped!
# 459 / 543 agents scraped!
# 460 / 543 agents scraped!
# 461 / 543 agents scraped!
# 462 / 543 agents scraped!
# 463 / 543 agents scraped!
# 464 / 543 agents scraped!
# 465 / 543 agents scraped!
# 466 / 543 agents scraped!
# 467 / 543 agents scraped!
# 468 / 543 agents scraped!
# 469 / 543 agents scraped!
# 470 / 543 agents scraped!
# 471 / 543 agents scraped!
# 472 / 543 agents scraped!
# 473 / 543 agents scraped!
# 474 / 543 agents scraped!
# 475 / 543 agents scraped!
# 476 / 543 agents scraped!
# 477 / 543 agents scraped!
# 478 / 543 agents scraped!
# 479 / 543 agents scraped!
# 480 / 543 agents scraped!
# 481 / 543 agents scraped!
# 482 / 543 agents scraped!
# 483 / 543 agents scraped!
# 484 / 543 agents scraped!
# 485 / 543 agents scraped!
# 486 / 543 agents scraped!
# 487 / 543 agents scraped!
# 488 / 543 agents scraped!
# 489 / 543 agents scraped!
# 490 / 543 agents scraped!
# 491 / 543 agents scraped!
# 492 / 543 agents scraped!
# 493 / 543 agents scraped!
# 494 / 543 agents scraped!
# 495 / 543 agents scraped!
# 496 / 543 agents scraped!
# 497 / 543 agents scraped!
# 498 / 543 agents scraped!
# 499 / 543 agents scraped!
# 500 / 543 agents scraped!
# 501 / 543 agents scraped!
# 502 / 543 agents scraped!
# 503 / 543 agents scraped!
# 504 / 543 agents scraped!
# 505 / 543 agents scraped!
# 506 / 543 agents scraped!
# 507 / 543 agents scraped!
# 508 / 543 agents scraped!
# 509 / 543 agents scraped!
# 510 / 543 agents scraped!
# 511 / 543 agents scraped!
# 512 / 543 agents scraped!
# 513 / 543 agents scraped!
# 514 / 543 agents scraped!
# 515 / 543 agents scraped!
# 516 / 543 agents scraped!
# 517 / 543 agents scraped!
# 518 / 543 agents scraped!
# 519 / 543 agents scraped!
# 520 / 543 agents scraped!
# 521 / 543 agents scraped!
# 522 / 543 agents scraped!
# 523 / 543 agents scraped!
# 524 / 543 agents scraped!
# 525 / 543 agents scraped!
# 526 / 543 agents scraped!
# 527 / 543 agents scraped!
# 528 / 543 agents scraped!
# 529 / 543 agents scraped!
# 530 / 543 agents scraped!
# 531 / 543 agents scraped!
# 532 / 543 agents scraped!
# 533 / 543 agents scraped!
# 534 / 543 agents scraped!
# 535 / 543 agents scraped!
# 536 / 543 agents scraped!
# 537 / 543 agents scraped!
# 538 / 543 agents scraped!
# 539 / 543 agents scraped!
# 540 / 543 agents scraped!
# 541 / 543 agents scraped!
# 542 / 543 agents scraped!
# 543 / 543 agents scraped!
