# %%
import json
import requests


from bs4 import BeautifulSoup as bs

# %%
base_url = 'https://nflpa.com'
# first_page_url = f'{base_url}/search/agents?page=1'

# response = requests.get(url=first_page_url)

# if response.status_code == 200:
#     first_page_html = bs(response.text, features="html.parser")
    
#     page_urls = [first_page_url] + [a['href'] for a in first_page_html.find('div', class_='pagination__pages').findAll('a')]

# %%
def scrape_agent_page(agent_page_url):
    
    try:
        
        print(f"Scraping additional data for {agent_page_url}...")
        
        response = requests.get(url=f"{base_url}{agent_page_url}")

        if response.status_code < 400:
            agent_html = bs(response.text, features="html.parser")
        else:
            response.raise_for_status()
    
        top_half_html = agent_html.findAll('div', class_='profile__content')[0]
        bot_half_html = agent_html.findAll('div', class_='profile__content')[1]
        
        try:
            certified = top_half_html.find('div', class_='flex items-center').text.strip()
        except AttributeError:
            certified = None
            
        try:
            detailed_address = top_half_html.find('ul', 'profile__icon-list mt-4').findAll('li')[0].text.replace('  ', '').replace('\n\n', ' ').replace('\n', ' ').strip()        
        except (AttributeError, IndexError):
            detailed_address = None
        
        try:
            phone_nbr = top_half_html.find('ul', 'profile__icon-list mt-4').findAll('li')[1].text.replace('  ', '').replace('\n\n', ' ').replace('\n', ' ').strip(),
        except (AttributeError, IndexError):
            phone_nbr = None
            
        try:
            services = [item.text.strip() for item in bot_half_html.find('div', class_='profile__section').findAll('li')]
        except AttributeError:
            services = None
            
        try:
            other_contact = [item.find('a')['href'] for item in bot_half_html.find('ul', class_='profile__icon-list').findAll('li')]
        except AttributeError:
            other_contact = None
        
        try:
            education = [item.text.replace('  ', '').replace('\n\n', ' ').replace('\n', ' ').strip()    for item in bot_half_html.findAll('div', class_='flex')]
        except AttributeError:
            education = None
        
        extras_obj = {
            "certified": certified,
            "detailed_address": detailed_address,
            "phone_nbr": phone_nbr,
            "services": services,
            "other_contact": other_contact, 
            "education": education,
        }
        
        return extras_obj
        
    except:
        raise

# %%
def scrape_table_row(table_row):
    
    cols = table_row.findAll('td')

    row_obj = {
        "name": cols[0].text.strip(),
        "company": cols[1].text.strip(),
        "company_address": cols[2].text.strip(),
        "url": cols[0].find('a')['href'],
        "additional_data": scrape_agent_page(cols[0].find('a')['href']),
    }
    
    return row_obj

# %%
def scrape_main_table(page_url):
    
    print(f"Finding agents on {page_url}...")
    
    try:
        response = requests.get(url=page_url)

        if response.status_code < 400:
            first_page_html = bs(response.text, features="html.parser")
        else:
            response.raise_for_status()
            
        
        html_table = first_page_html.find('table', class_='search-results results-table')
        
        data = []
        
        print(f"Found {len(html_table.findAll('tr')[1:])} agents to scrape!")
        
        for row in html_table.findAll('tr')[1:]:
            row_data = scrape_table_row(row)
            
            data.append(row_data)
        
        return data
    
    except:
        raise

# %%
def gather_page_urls(page_url, page_url_list):
    try:
        
        response = requests.get(url=page_url)

        if response.status_code < 400:
            page_html = bs(response.text, features="html.parser")
        else:
            response.raise_for_status()
            
        for url in page_html.find('div', class_='pagination__pages').findAll('a'):
            if url['href'] != "https://nflpa.com/search/agents" and url['href'] not in page_url_list:
                page_url_list.append(url['href'])
                gather_page_urls(page_url=url['href'], page_url_list=page_url_list)
                
        return page_url_list
    
    except:
        raise

# %%
data = []

try:
    
    page_urls = gather_page_urls(f'{base_url}/search/agents?page=1', [f'{base_url}/search/agents?page=1'])
    
    print(f"Found {len(page_urls)} pages of agents to scrape!")

    for page_url in page_urls:
        page_data = scrape_main_table(page_url=page_url)
        data = data + page_data

except:
    raise
# Out:
# Found 31 pages of agents to scrape!
# Finding agents on https://nflpa.com/search/agents?page=1...
# Found 25 agents to scrape!
# Scraping additional data for /profile/agent/31023...
# Scraping additional data for /profile/agent/46768...
# Scraping additional data for /profile/agent/48348...
# Scraping additional data for /profile/agent/62580...
# Scraping additional data for /profile/agent/46769...
# Scraping additional data for /profile/agent/41793...
# Scraping additional data for /profile/agent/00050...
# Scraping additional data for /profile/agent/62575...
# Scraping additional data for /profile/agent/62599...
# Scraping additional data for /profile/agent/41795...
# Scraping additional data for /profile/agent/63649...
# Scraping additional data for /profile/agent/48351...
# Scraping additional data for /profile/agent/48352...
# Scraping additional data for /profile/agent/19498...
# Scraping additional data for /profile/agent/45550...
# Scraping additional data for /profile/agent/62600...
# Scraping additional data for /profile/agent/46773...
# Scraping additional data for /profile/agent/66518...
# Scraping additional data for /profile/agent/37085...
# Scraping additional data for /profile/agent/55910...
# Scraping additional data for /profile/agent/48353...
# Scraping additional data for /profile/agent/41798...
# Scraping additional data for /profile/agent/55912...
# Scraping additional data for /profile/agent/37036...
# Scraping additional data for /profile/agent/38490...
# Finding agents on https://nflpa.com/search/agents?page=2...
# Found 25 agents to scrape!
# Scraping additional data for /profile/agent/54733...
# Scraping additional data for /profile/agent/66519...
# Scraping additional data for /profile/agent/18483...
# Scraping additional data for /profile/agent/34208...
# Scraping additional data for /profile/agent/28412...
# Scraping additional data for /profile/agent/21461...
# Scraping additional data for /profile/agent/15331...
# Scraping additional data for /profile/agent/43459...
# Scraping additional data for /profile/agent/39734...
# Scraping additional data for /profile/agent/45555...
# Scraping additional data for /profile/agent/37737...
# Scraping additional data for /profile/agent/00421...
# Scraping additional data for /profile/agent/34409...
# Scraping additional data for /profile/agent/30956...
# Scraping additional data for /profile/agent/62511...
# Scraping additional data for /profile/agent/22213...
# Scraping additional data for /profile/agent/00476...
# Scraping additional data for /profile/agent/25571...
# Scraping additional data for /profile/agent/66521...
# Scraping additional data for /profile/agent/10326...
# Scraping additional data for /profile/agent/62596...
# Scraping additional data for /profile/agent/25708...
# Scraping additional data for /profile/agent/49461...
# Scraping additional data for /profile/agent/55918...
# Scraping additional data for /profile/agent/55920...
# Finding agents on https://nflpa.com/search/agents?page=3...
# Found 25 agents to scrape!
# Scraping additional data for /profile/agent/49462...
# Scraping additional data for /profile/agent/62505...
# Scraping additional data for /profile/agent/49464...
# Scraping additional data for /profile/agent/54737...
# Scraping additional data for /profile/agent/35425...
# Scraping additional data for /profile/agent/00599...
# Scraping additional data for /profile/agent/48657...
# Scraping additional data for /profile/agent/46777...
# Scraping additional data for /profile/agent/38201...
# Scraping additional data for /profile/agent/36985...
# Scraping additional data for /profile/agent/41388...
# Scraping additional data for /profile/agent/38859...
# Scraping additional data for /profile/agent/46778...
# Scraping additional data for /profile/agent/29763...
# Scraping additional data for /profile/agent/45561...
# Scraping additional data for /profile/agent/00699...
# Scraping additional data for /profile/agent/45562...
# Scraping additional data for /profile/agent/34320...
# Scraping additional data for /profile/agent/45563...
# Scraping additional data for /profile/agent/48362...
# Scraping additional data for /profile/agent/62484...
# Scraping additional data for /profile/agent/62523...
# Scraping additional data for /profile/agent/62493...
# Scraping additional data for /profile/agent/66526...
# Scraping additional data for /profile/agent/55921...
# Finding agents on https://nflpa.com/search/agents?page=4...
# Found 25 agents to scrape!
# Scraping additional data for /profile/agent/36937...
# Scraping additional data for /profile/agent/41394...
# Scraping additional data for /profile/agent/13759...
# Scraping additional data for /profile/agent/24698...
# Scraping additional data for /profile/agent/16783...
# Scraping additional data for /profile/agent/46781...
# Scraping additional data for /profile/agent/55924...
# Scraping additional data for /profile/agent/66529...
# Scraping additional data for /profile/agent/62625...
# Scraping additional data for /profile/agent/45567...
# Scraping additional data for /profile/agent/43490...
# Scraping additional data for /profile/agent/41815...
# Scraping additional data for /profile/agent/54745...
# Scraping additional data for /profile/agent/66530...
# Scraping additional data for /profile/agent/29935...
# Scraping additional data for /profile/agent/48344...
# Scraping additional data for /profile/agent/55928...
# Scraping additional data for /profile/agent/62538...
# Scraping additional data for /profile/agent/45571...
# Scraping additional data for /profile/agent/36908...
# Scraping additional data for /profile/agent/54746...
# Scraping additional data for /profile/agent/46790...
# Scraping additional data for /profile/agent/29889...
# Scraping additional data for /profile/agent/41820...
# Scraping additional data for /profile/agent/39743...
# Finding agents on https://nflpa.com/search/agents?page=5...
# Found 25 agents to scrape!
# Scraping additional data for /profile/agent/41821...
# Scraping additional data for /profile/agent/41822...
# Scraping additional data for /profile/agent/66533...
# Scraping additional data for /profile/agent/43528...
# Scraping additional data for /profile/agent/43438...
# Scraping additional data for /profile/agent/25543...
# Scraping additional data for /profile/agent/40522...
# Scraping additional data for /profile/agent/30994...
# Scraping additional data for /profile/agent/36940...
# Scraping additional data for /profile/agent/41401...
# Scraping additional data for /profile/agent/39745...
# Scraping additional data for /profile/agent/66534...
# Scraping additional data for /profile/agent/43588...
# Scraping additional data for /profile/agent/66535...
# Scraping additional data for /profile/agent/40632...
# Scraping additional data for /profile/agent/54748...
# Scraping additional data for /profile/agent/26745...
# Scraping additional data for /profile/agent/14433...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-4ade2e5bc415> in <module>
#       8
#       9     for page_url in page_urls:
# ---> 10         page_data = scrape_main_table(page_url=page_url)
#      11         data = data + page_data
#      12
#
# <ipython-input-17-2faf2cab7982> in scrape_main_table(page_url)
#      19
#      20         for row in html_table.findAll('tr')[1:]:
# ---> 21             row_data = scrape_table_row(row)
#      22
#      23             data.append(row_data)
#
# <ipython-input-16-67e83143d4df> in scrape_table_row(table_row)
#       8         "company_address": cols[2].text.strip(),
#       9         "url": cols[0].find('a')['href'],
# ---> 10         "additional_data": scrape_agent_page(cols[0].find('a')['href']),
#      11     }
#      12
#
# <ipython-input-15-65fd780dd062> in scrape_agent_page(agent_page_url)
#       5         print(f"Scraping additional data for {agent_page_url}...")
#       6
# ----> 7         response = requests.get(url=f"{base_url}{agent_page_url}")
#       8
#       9         if response.status_code < 400:
#
# C:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# C:\Anaconda3\lib\http\client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# C:\Anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# C:\Anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# C:\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# C:\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
